# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0539/NASSCOM-LAB/blob/main/Python_Core_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}
DEVICE_TYPES = [
    'Temperature_Sensor',
    'Humidity_Sensor',
    'Pressure_Sensor',
    'Light_Sensor'
]

LOCATIONS = [
    'Lab1',
    'Lab2',
    'OfficeA',
    'OfficeB',
    'Warehouse'
]

READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}

raw_sensor_data = []

for i in range(1, 101):

    timestamp_str = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    device_id = f"DEV{i:03d}"

    device_type = random.choice(DEVICE_TYPES)

    location = random.choice(LOCATIONS)

    min_value, max_value = READING_RANGES[device_type]
    value = round(random.uniform(min_value, max_value), 2)

    reading = (timestamp_str, device_id, device_type, location, value)

    raw_sensor_data.append(reading)

print("\nGenerated Sensor Readings:")
for reading in raw_sensor_data:
    print(reading)
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# Generated Sensor Readings:
# ('2026-07-19 15:48:07', 'DEV001', 'Temperature_Sensor', 'Lab2', 29.4)
# ('2026-07-19 15:48:07', 'DEV002', 'Light_Sensor', 'Lab1', 462.67)
# ('2026-07-19 15:48:07', 'DEV003', 'Temperature_Sensor', 'OfficeB', 27.84)
# ('2026-07-19 15:48:07', 'DEV004', 'Light_Sensor', 'Lab2', 807.02)
# ('2026-07-19 15:48:07', 'DEV005', 'Humidity_Sensor', 'OfficeA', 73.82)
# ('2026-07-19 15:48:07', 'DEV006', 'Humidity_Sensor', 'OfficeA', 58.59)
# ('2026-07-19 15:48:07', 'DEV007', 'Pressure_Sensor', 'OfficeB', 1003.79)
# ('2026-07-19 15:48:07', 'DEV008', 'Humidity_Sensor', 'Lab1', 59.92)
# ('2026-07-19 15:48:07', 'DEV009', 'Pressure_Sensor', 'Warehouse', 1000.7)
# ('2026-07-19 15:48:07', 'DEV010', 'Pressure_Sensor', 'Lab2', 986.97)
# ('2026-07-19 15:48:07', 'DEV011', 'Humidity_Sensor', 'Lab2', 55.9)
# ('2026-07-19 15:48:07', 'DEV012', 'Temperature_Sensor', 'Lab1', 25.14)
# ('2026-07-19 15:48:07', 'DEV013', 'Humidity_Sensor', 'OfficeB', 40.61)
# ('2026-07-19 15:48:07', 'DEV014', 'Pressure_Sensor', 'Warehouse', 1008.01)
# ('2026-07-19 15:48:07', 'DEV015', 'Humidity_Sensor', 'Lab2', 57.3)
# ('2026-07-19 15:48:07', 'DEV016', 'Pressure_Sensor', 'Lab1', 1005.54)
# ('2026-07-19 15:48:07', 'DEV017', 'Light_Sensor', 'OfficeB', 481.75)
# ('2026-07-19 15:48:07', 'DEV018', 'Pressure_Sensor', 'OfficeA', 1023.38)
# ('2026-07-19 15:48:07', 'DEV019', 'Temperature_Sensor', 'Lab2', 24.59)
# ('2026-07-19 15:48:07', 'DEV020', 'Light_Sensor', 'Warehouse', 763.97)
# ('2026-07-19 15:48:07', 'DEV021', 'Humidity_Sensor', 'Warehouse', 74.81)
# ('2026-07-19 15:48:07', 'DEV022', 'Temperature_Sensor', 'OfficeB', 18.06)
# ('2026-07-19 15:48:07', 'DEV023', 'Temperature_Sensor', 'OfficeA', 25.69)
# ('2026-07-19 15:48:07', 'DEV024', 'Light_Sensor', 'OfficeA', 745.88)
# ('2026-07-19 15:48:07', 'DEV025', 'Pressure_Sensor', 'OfficeB', 1016.0)
# ('2026-07-19 15:48:07', 'DEV026', 'Humidity_Sensor', 'OfficeB', 34.25)
# ('2026-07-19 15:48:07', 'DEV027', 'Pressure_Sensor', 'OfficeA', 1012.33)
# ('2026-07-19 15:48:07', 'DEV028', 'Humidity_Sensor', 'Lab2', 47.23)
# ('2026-07-19 15:48:07', 'DEV029', 'Light_Sensor', 'Lab1', 571.96)
# ('2026-07-19 15:48:07', 'DEV030', 'Light_Sensor', 'OfficeA', 623.79)
# ('2026-07-19 15:48:07', 'DEV031', 'Light_Sensor', 'Lab2', 824.97)
# ('2026-07-19 15:48:07', 'DEV032', 'Temperature_Sensor', 'Lab1', 21.31)
# ('2026-07-19 15:48:07', 'DEV033', 'Temperature_Sensor', 'Warehouse', 18.22)
# ('2026-07-19 15:48:07', 'DEV034', 'Humidity_Sensor', 'Warehouse', 35.52)
# ('2026-07-19 15:48:07', 'DEV035', 'Temperature_Sensor', 'Lab1', 20.74)
# ('2026-07-19 15:48:07', 'DEV036', 'Temperature_Sensor', 'OfficeA', 20.14)
# ('2026-07-19 15:48:07', 'DEV037', 'Humidity_Sensor', 'Lab2', 79.4)
# ('2026-07-19 15:48:07', 'DEV038', 'Humidity_Sensor', 'Lab2', 41.52)
# ('2026-07-19 15:48:07', 'DEV039', 'Humidity_Sensor', 'Lab1', 40.64)
# ('2026-07-19 15:48:07', 'DEV040', 'Light_Sensor', 'Lab1', 143.09)
# ('2026-07-19 15:48:07', 'DEV041', 'Temperature_Sensor', 'Lab2', 26.14)
# ('2026-07-19 15:48:07', 'DEV042', 'Light_Sensor', 'Lab2', 390.02)
# ('2026-07-19 15:48:07', 'DEV043', 'Light_Sensor', 'Lab2', 960.24)
# ('2026-07-19 15:48:07', 'DEV044', 'Pressure_Sensor', 'OfficeB', 1001.43)
# ('2026-07-19 15:48:07', 'DEV045', 'Pressure_Sensor', 'OfficeA', 1002.87)
# ('2026-07-19 15:48:07', 'DEV046', 'Temperature_Sensor', 'OfficeB', 22.29)
# ('2026-07-19 15:48:07', 'DEV047', 'Pressure_Sensor', 'OfficeA', 1001.78)
# ('2026-07-19 15:48:07', 'DEV048', 'Pressure_Sensor', 'Warehouse', 1024.92)
# ('2026-07-19 15:48:07', 'DEV049', 'Temperature_Sensor', 'Lab1', 19.84)
# ('2026-07-19 15:48:07', 'DEV050', 'Pressure_Sensor', 'OfficeA', 1025.67)
# ('2026-07-19 15:48:07', 'DEV051', 'Light_Sensor', 'OfficeA', 623.93)
# ('2026-07-19 15:48:07', 'DEV052', 'Temperature_Sensor', 'Warehouse', 19.17)
# ('2026-07-19 15:48:07', 'DEV053', 'Pressure_Sensor', 'Lab1', 1001.31)
# ('2026-07-19 15:48:07', 'DEV054', 'Light_Sensor', 'OfficeB', 816.54)
# ('2026-07-19 15:48:07', 'DEV055', 'Light_Sensor', 'Lab1', 740.62)
# ('2026-07-19 15:48:07', 'DEV056', 'Pressure_Sensor', 'OfficeB', 1016.72)
# ('2026-07-19 15:48:07', 'DEV057', 'Pressure_Sensor', 'Warehouse', 990.57)
# ('2026-07-19 15:48:07', 'DEV058', 'Temperature_Sensor', 'Lab2', 29.22)
# ('2026-07-19 15:48:07', 'DEV059', 'Humidity_Sensor', 'Lab1', 42.55)
# ('2026-07-19 15:48:07', 'DEV060', 'Light_Sensor', 'Warehouse', 467.3)
# ('2026-07-19 15:48:07', 'DEV061', 'Humidity_Sensor', 'OfficeA', 47.74)
# ('2026-07-19 15:48:07', 'DEV062', 'Humidity_Sensor', 'OfficeA', 45.71)
# ('2026-07-19 15:48:07', 'DEV063', 'Pressure_Sensor', 'Lab1', 995.3)
# ('2026-07-19 15:48:07', 'DEV064', 'Humidity_Sensor', 'OfficeA', 62.08)
# ('2026-07-19 15:48:07', 'DEV065', 'Light_Sensor', 'OfficeB', 713.19)
# ('2026-07-19 15:48:07', 'DEV066', 'Humidity_Sensor', 'OfficeB', 76.42)
# ('2026-07-19 15:48:07', 'DEV067', 'Humidity_Sensor', 'Lab2', 42.63)
# ('2026-07-19 15:48:07', 'DEV068', 'Humidity_Sensor', 'Lab1', 74.22)
# ('2026-07-19 15:48:07', 'DEV069', 'Pressure_Sensor', 'Lab2', 993.98)
# ('2026-07-19 15:48:07', 'DEV070', 'Light_Sensor', 'OfficeA', 957.86)
# ('2026-07-19 15:48:07', 'DEV071', 'Pressure_Sensor', 'OfficeA', 1009.96)
# ('2026-07-19 15:48:07', 'DEV072', 'Humidity_Sensor', 'Lab2', 47.85)
# ('2026-07-19 15:48:07', 'DEV073', 'Temperature_Sensor', 'Lab1', 21.26)
# ('2026-07-19 15:48:07', 'DEV074', 'Humidity_Sensor', 'OfficeA', 71.6)
# ('2026-07-19 15:48:07', 'DEV075', 'Light_Sensor', 'OfficeB', 899.17)
# ('2026-07-19 15:48:07', 'DEV076', 'Temperature_Sensor', 'Lab1', 21.33)
# ('2026-07-19 15:48:07', 'DEV077', 'Pressure_Sensor', 'OfficeB', 1021.77)
# ('2026-07-19 15:48:07', 'DEV078', 'Pressure_Sensor', 'Lab1', 1026.66)
# ('2026-07-19 15:48:07', 'DEV079', 'Pressure_Sensor', 'Warehouse', 1027.26)
# ('2026-07-19 15:48:07', 'DEV080', 'Light_Sensor', 'Warehouse', 126.75)
# ('2026-07-19 15:48:07', 'DEV081', 'Pressure_Sensor', 'OfficeA', 988.36)
# ('2026-07-19 15:48:07', 'DEV082', 'Humidity_Sensor', 'OfficeA', 48.75)
# ('2026-07-19 15:48:07', 'DEV083', 'Light_Sensor', 'OfficeB', 681.31)
# ('2026-07-19 15:48:07', 'DEV084', 'Light_Sensor', 'OfficeA', 981.98)
# ('2026-07-19 15:48:07', 'DEV085', 'Temperature_Sensor', 'Lab1', 23.42)
# ('2026-07-19 15:48:07', 'DEV086', 'Humidity_Sensor', 'OfficeB', 64.44)
# ('2026-07-19 15:48:07', 'DEV087', 'Light_Sensor', 'Lab2', 827.08)
# ('2026-07-19 15:48:07', 'DEV088', 'Humidity_Sensor', 'Lab2', 60.33)
# ('2026-07-19 15:48:07', 'DEV089', 'Pressure_Sensor', 'Warehouse', 984.69)
# ('2026-07-19 15:48:07', 'DEV090', 'Light_Sensor', 'Warehouse', 567.66)
# ('2026-07-19 15:48:07', 'DEV091', 'Humidity_Sensor', 'Warehouse', 35.84)
# ('2026-07-19 15:48:07', 'DEV092', 'Humidity_Sensor', 'OfficeB', 63.07)
# ('2026-07-19 15:48:07', 'DEV093', 'Pressure_Sensor', 'Lab1', 1008.38)
# ('2026-07-19 15:48:07', 'DEV094', 'Humidity_Sensor', 'OfficeA', 31.74)
# ('2026-07-19 15:48:07', 'DEV095', 'Pressure_Sensor', 'OfficeA', 1023.06)
# ('2026-07-19 15:48:07', 'DEV096', 'Temperature_Sensor', 'Lab1', 28.49)
# ('2026-07-19 15:48:07', 'DEV097', 'Light_Sensor', 'Warehouse', 980.21)
# ('2026-07-19 15:48:07', 'DEV098', 'Light_Sensor', 'OfficeA', 557.83)
# ('2026-07-19 15:48:07', 'DEV099', 'Light_Sensor', 'Lab2', 527.74)
# ('2026-07-19 15:48:07', 'DEV100', 'Humidity_Sensor', 'OfficeA', 77.53)

# %%
temperature_readings = []

for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading

    if device_type == "Temperature_Sensor":
        temp_dict = {
            "timestamp": timestamp,
            "device_id": device_id,
            "location": location,
            "temperature_celsius": value
        }

        temperature_readings.append(temp_dict)

print("\nTemperature Readings:")
for temp in temperature_readings:
    print(temp)
# Out:
# Temperature Readings:
# {'timestamp': '2026-07-19 15:48:07', 'device_id': 'DEV001', 'location': 'Lab2', 'temperature_celsius': 29.4}
# {'timestamp': '2026-07-19 15:48:07', 'device_id': 'DEV003', 'location': 'OfficeB', 'temperature_celsius': 27.84}
# {'timestamp': '2026-07-19 15:48:07', 'device_id': 'DEV012', 'location': 'Lab1', 'temperature_celsius': 25.14}
# {'timestamp': '2026-07-19 15:48:07', 'device_id': 'DEV019', 'location': 'Lab2', 'temperature_celsius': 24.59}
# {'timestamp': '2026-07-19 15:48:07', 'device_id': 'DEV022', 'location': 'OfficeB', 'temperature_celsius': 18.06}
# {'timestamp': '2026-07-19 15:48:07', 'device_id': 'DEV023', 'location': 'OfficeA', 'temperature_celsius': 25.69}
# {'timestamp': '2026-07-19 15:48:07', 'device_id': 'DEV032', 'location': 'Lab1', 'temperature_celsius': 21.31}
# {'timestamp': '2026-07-19 15:48:07', 'device_id': 'DEV033', 'location': 'Warehouse', 'temperature_celsius': 18.22}
# {'timestamp': '2026-07-19 15:48:07', 'device_id': 'DEV035', 'location': 'Lab1', 'temperature_celsius': 20.74}
# {'timestamp': '2026-07-19 15:48:07', 'device_id': 'DEV036', 'location': 'OfficeA', 'temperature_celsius': 20.14}
# {'timestamp': '2026-07-19 15:48:07', 'device_id': 'DEV041', 'location': 'Lab2', 'temperature_celsius': 26.14}
# {'timestamp': '2026-07-19 15:48:07', 'device_id': 'DEV046', 'location': 'OfficeB', 'temperature_celsius': 22.29}
# {'timestamp': '2026-07-19 15:48:07', 'device_id': 'DEV049', 'location': 'Lab1', 'temperature_celsius': 19.84}
# {'timestamp': '2026-07-19 15:48:07', 'device_id': 'DEV052', 'location': 'Warehouse', 'temperature_celsius': 19.17}
# {'timestamp': '2026-07-19 15:48:07', 'device_id': 'DEV058', 'location': 'Lab2', 'temperature_celsius': 29.22}
# {'timestamp': '2026-07-19 15:48:07', 'device_id': 'DEV073', 'location': 'Lab1', 'temperature_celsius': 21.26}
# {'timestamp': '2026-07-19 15:48:07', 'device_id': 'DEV076', 'location': 'Lab1', 'temperature_celsius': 21.33}
# {'timestamp': '2026-07-19 15:48:07', 'device_id': 'DEV085', 'location': 'Lab1', 'temperature_celsius': 23.42}
# {'timestamp': '2026-07-19 15:48:07', 'device_id': 'DEV096', 'location': 'Lab1', 'temperature_celsius': 28.49}

# %%
unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])

print("\nUnique Locations:")
print(unique_locations)
# Out:
# Unique Locations:
# {'Lab2', 'OfficeB', 'Warehouse', 'Lab1', 'OfficeA'}

# %%
device_stats = {}

for device in DEVICE_TYPES:
    device_stats[device] = (float('inf'), float('-inf'))

for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    min_value, max_value = device_stats[device_type]

    if value < min_value:
        min_value = value

    if value > max_value:
        max_value = value

    device_stats[device_type] = (min_value, max_value)

print("\nDevice Statistics:")
for device, stats in device_stats.items():
    print(device, ":", stats)
# Out:
# Device Statistics:
# Temperature_Sensor : (18.06, 29.4)
# Humidity_Sensor : (31.74, 79.4)
# Pressure_Sensor : (984.69, 1027.26)
# Light_Sensor : (126.75, 981.98)

# %%
print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")
sample_string = "PythonProgrammingIsFun"

sliced_readings_1 = raw_sensor_data[9:20]

sliced_readings_2 = raw_sensor_data[::5]

print("\nReadings from 10th to 20th (inclusive):")
for reading in sliced_readings_1:
    print(reading)

print("\nEvery 5th reading:")
for reading in sliced_readings_2:
    print(reading)
# Out:
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
#
# Readings from 10th to 20th (inclusive):
# ('2026-07-19 15:48:07', 'DEV010', 'Pressure_Sensor', 'Lab2', 986.97)
# ('2026-07-19 15:48:07', 'DEV011', 'Humidity_Sensor', 'Lab2', 55.9)
# ('2026-07-19 15:48:07', 'DEV012', 'Temperature_Sensor', 'Lab1', 25.14)
# ('2026-07-19 15:48:07', 'DEV013', 'Humidity_Sensor', 'OfficeB', 40.61)
# ('2026-07-19 15:48:07', 'DEV014', 'Pressure_Sensor', 'Warehouse', 1008.01)
# ('2026-07-19 15:48:07', 'DEV015', 'Humidity_Sensor', 'Lab2', 57.3)
# ('2026-07-19 15:48:07', 'DEV016', 'Pressure_Sensor', 'Lab1', 1005.54)
# ('2026-07-19 15:48:07', 'DEV017', 'Light_Sensor', 'OfficeB', 481.75)
# ('2026-07-19 15:48:07', 'DEV018', 'Pressure_Sensor', 'OfficeA', 1023.38)
# ('2026-07-19 15:48:07', 'DEV019', 'Temperature_Sensor', 'Lab2', 24.59)
# ('2026-07-19 15:48:07', 'DEV020', 'Light_Sensor', 'Warehouse', 763.97)
#
# Every 5th reading:
# ('2026-07-19 15:48:07', 'DEV001', 'Temperature_Sensor', 'Lab2', 29.4)
# ('2026-07-19 15:48:07', 'DEV006', 'Humidity_Sensor', 'OfficeA', 58.59)
# ('2026-07-19 15:48:07', 'DEV011', 'Humidity_Sensor', 'Lab2', 55.9)
# ('2026-07-19 15:48:07', 'DEV016', 'Pressure_Sensor', 'Lab1', 1005.54)
# ('2026-07-19 15:48:07', 'DEV021', 'Humidity_Sensor', 'Warehouse', 74.81)
# ('2026-07-19 15:48:07', 'DEV026', 'Humidity_Sensor', 'OfficeB', 34.25)
# ('2026-07-19 15:48:07', 'DEV031', 'Light_Sensor', 'Lab2', 824.97)
# ('2026-07-19 15:48:07', 'DEV036', 'Temperature_Sensor', 'OfficeA', 20.14)
# ('2026-07-19 15:48:07', 'DEV041', 'Temperature_Sensor', 'Lab2', 26.14)
# ('2026-07-19 15:48:07', 'DEV046', 'Temperature_Sensor', 'OfficeB', 22.29)
# ('2026-07-19 15:48:07', 'DEV051', 'Light_Sensor', 'OfficeA', 623.93)
# ('2026-07-19 15:48:07', 'DEV056', 'Pressure_Sensor', 'OfficeB', 1016.72)
# ('2026-07-19 15:48:07', 'DEV061', 'Humidity_Sensor', 'OfficeA', 47.74)
# ('2026-07-19 15:48:07', 'DEV066', 'Humidity_Sensor', 'OfficeB', 76.42)
# ('2026-07-19 15:48:07', 'DEV071', 'Pressure_Sensor', 'OfficeA', 1009.96)
# ('2026-07-19 15:48:07', 'DEV076', 'Temperature_Sensor', 'Lab1', 21.33)
# ('2026-07-19 15:48:07', 'DEV081', 'Pressure_Sensor', 'OfficeA', 988.36)
# ('2026-07-19 15:48:07', 'DEV086', 'Humidity_Sensor', 'OfficeB', 64.44)
# ('2026-07-19 15:48:07', 'DEV091', 'Humidity_Sensor', 'Warehouse', 35.84)
# ('2026-07-19 15:48:07', 'DEV096', 'Temperature_Sensor', 'Lab1', 28.49)

# %%
substring_1 = sample_string[6:17]

substring_2 = sample_string[5::-1]

print("\nSubstring 1:", substring_1)
print("Substring 2:", substring_2)
# Out:
# Substring 1: Programming
# Substring 2: nohtyP

# %%
fifth_reading_device_type = raw_sensor_data[4][2]

device_type_suffix = fifth_reading_device_type[-6:]

print("\n5th Reading Device Type:", fifth_reading_device_type)
print("Device Type Suffix:", device_type_suffix)
# Out:
# 5th Reading Device Type: Humidity_Sensor
# Device Type Suffix: Sensor

# %%
print("\n--- Task 2: Function Definitions and Usage ---")

def get_readings_by_location(readings_list, target_location):
    result = []

    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)

    return result


location = "Lab1"
lab1_readings = get_readings_by_location(raw_sensor_data, location)

print(f"\nSensor Readings for {location}:")
for reading in lab1_readings:
    print(reading)
# Out:
# --- Task 2: Function Definitions and Usage ---
#
# Sensor Readings for Lab1:
# ('2026-07-19 15:48:07', 'DEV002', 'Light_Sensor', 'Lab1', 462.67)
# ('2026-07-19 15:48:07', 'DEV008', 'Humidity_Sensor', 'Lab1', 59.92)
# ('2026-07-19 15:48:07', 'DEV012', 'Temperature_Sensor', 'Lab1', 25.14)
# ('2026-07-19 15:48:07', 'DEV016', 'Pressure_Sensor', 'Lab1', 1005.54)
# ('2026-07-19 15:48:07', 'DEV029', 'Light_Sensor', 'Lab1', 571.96)
# ('2026-07-19 15:48:07', 'DEV032', 'Temperature_Sensor', 'Lab1', 21.31)
# ('2026-07-19 15:48:07', 'DEV035', 'Temperature_Sensor', 'Lab1', 20.74)
# ('2026-07-19 15:48:07', 'DEV039', 'Humidity_Sensor', 'Lab1', 40.64)
# ('2026-07-19 15:48:07', 'DEV040', 'Light_Sensor', 'Lab1', 143.09)
# ('2026-07-19 15:48:07', 'DEV049', 'Temperature_Sensor', 'Lab1', 19.84)
# ('2026-07-19 15:48:07', 'DEV053', 'Pressure_Sensor', 'Lab1', 1001.31)
# ('2026-07-19 15:48:07', 'DEV055', 'Light_Sensor', 'Lab1', 740.62)
# ('2026-07-19 15:48:07', 'DEV059', 'Humidity_Sensor', 'Lab1', 42.55)
# ('2026-07-19 15:48:07', 'DEV063', 'Pressure_Sensor', 'Lab1', 995.3)
# ('2026-07-19 15:48:07', 'DEV068', 'Humidity_Sensor', 'Lab1', 74.22)
# ('2026-07-19 15:48:07', 'DEV073', 'Temperature_Sensor', 'Lab1', 21.26)
# ('2026-07-19 15:48:07', 'DEV076', 'Temperature_Sensor', 'Lab1', 21.33)
# ('2026-07-19 15:48:07', 'DEV078', 'Pressure_Sensor', 'Lab1', 1026.66)
# ('2026-07-19 15:48:07', 'DEV085', 'Temperature_Sensor', 'Lab1', 23.42)
# ('2026-07-19 15:48:07', 'DEV093', 'Pressure_Sensor', 'Lab1', 1008.38)
# ('2026-07-19 15:48:07', 'DEV096', 'Temperature_Sensor', 'Lab1', 28.49)

# %%
def calculate_average_temperature(temp_data_list):
    if len(temp_data_list) == 0:
        return 0.0

    total = 0

    for reading in temp_data_list:
        total += reading["temperature_celsius"]

    average = total / len(temp_data_list)
    return round(average, 2)


avg_temperature = calculate_average_temperature(temperature_readings)

print("\nAverage Temperature:", avg_temperature)
# Out:
# Average Temperature: 23.28

# %%
def generate_report_line(reading_dict):
    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"


if len(temperature_readings) > 0:
    report = generate_report_line(temperature_readings[0])
    print("\nReport Line:")
    print(report)
# Out:
# Report Line:
# [2026-07-19 15:48:07] Device DEV001 at Lab2: 29.4°C

# %%
print("\n--- Task 3: Core Library Usage ---")


reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")
# Out:
# --- Task 3: Core Library Usage ---
#
# Directory 'sensor_reports' created.

# %%
if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    date_format = "%Y-%m-%d %H:%M:%S"

    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    duration = last_dt - first_dt

    days = duration.days
    hours = duration.seconds // 3600
    minutes = (duration.seconds % 3600) // 60

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")
# Out:
# Duration of data collection: 0 days, 0 hours, 0 minutes.

# %%
random_values = []

for i in range(5):
    random_values.append(random.randint(100, 200))

print("\nRandom Values:")
print(random_values)
# Out:
# Random Values:
# [141, 146, 160, 176, 181]
